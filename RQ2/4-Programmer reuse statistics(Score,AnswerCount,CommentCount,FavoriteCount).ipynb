# %%
from datetime import datetime
import time
import os
from tqdm import tqdm
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
path_dict = {0:'./1/', 1:'./2/', 2:'./3-5/',
             3:'./6-15/', 4:'./16-100/', 5:'./100/'}

# %%
df_list = []
for i in range(6):
    df = pd.read_excel(path_dict[i]+'so details.xlsx')
    print(df.info())
    df_list.append(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CreationDate   148 non-null    object
#  1   Title          148 non-null    object
#  2   Tags           148 non-null    object
#  3   Score          148 non-null    int64
#  4   AnswerCount    148 non-null    int64
#  5   CommentCount   148 non-null    int64
#  6   FavoriteCount  26 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 8.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CreationDate   137 non-null    object
#  1   Title          137 non-null    object
#  2   Tags           137 non-null    object
#  3   Score          137 non-null    int64
# ...

# %%
df1, df2, df3, df4, df5, df6 = df_list

# %%
Score1, Score2, Score3, Score4, Score5, Score6 = df1['Score'].dropna().to_list(),\
df2['Score'].dropna().to_list(),\
df3['Score'].dropna().to_list(),\
df4['Score'].dropna().to_list(),\
df5['Score'].dropna().to_list(),\
df6['Score'].dropna().to_list()

# %%
pd.DataFrame(Score1).describe()
# Out:
#                 0
# count  148.000000
# mean     1.479730
# std      4.325953
# min     -2.000000
# 25%      0.000000
# 50%      0.000000
# 75%      2.000000
# max     41.000000

# %%
# pd.DataFrame(Score1).boxplot(return_type='dict')

# %%
# Score1

# %%
Score = [Score1, Score2, Score3, Score4, Score5, Score6]

# %%
# df1['FavoriteCount'].dropna().to_list()

# %%
len(Score1),len(Score2),len(Score3),len(Score4),len(Score5),len(Score6)
# Out:
# (148, 137, 337, 740, 2051, 4818)

# %%
plt.figure(dpi=200)

plt.boxplot(Score,
            labels = [str(i) for i in range(1,7)],
            patch_artist=True,
            showmeans=True,
            boxprops = {'color':'black','facecolor':'#1E90FF'},
            showfliers = False,
            meanprops = {'marker':'o','markerfacecolor':'red'},
            medianprops = {'linestyle':'--','color':'black'},)
plt.grid()
plt.ylabel('Score')
# plt.yticks(range(2008, 2021), range(2008, 2021))
plt.xlabel('Interval')
# plt.xticks(rotation=45)
plt.savefig('./pic/Score.jpg')
plt.show()

# %%
AnswerCount1, AnswerCount2, AnswerCount3, AnswerCount4, AnswerCount5, AnswerCount6 = df1['AnswerCount'].dropna().to_list(),\
df2['AnswerCount'].dropna().to_list(),\
df3['AnswerCount'].dropna().to_list(),\
df4['AnswerCount'].dropna().to_list(),\
df5['AnswerCount'].dropna().to_list(),\
df6['AnswerCount'].dropna().to_list()



# AnswerCount1 = remove_filers_with_boxplot(pd.DataFrame(AnswerCount1))
# AnswerCount1 = AnswerCount1[0]
#
# AnswerCount2 = remove_filers_with_boxplot(pd.DataFrame(AnswerCount2))
# AnswerCount2 = AnswerCount2[0]
#
# AnswerCount3 = remove_filers_with_boxplot(pd.DataFrame(AnswerCount3))
# AnswerCount3 = AnswerCount3[0]
#
# AnswerCount4 = remove_filers_with_boxplot(pd.DataFrame(AnswerCount4))
# AnswerCount4 = AnswerCount4[0]
#
# AnswerCount5 = remove_filers_with_boxplot(pd.DataFrame(AnswerCount5))
# AnswerCount5 = AnswerCount5[0]
#
# AnswerCount6 = remove_filers_with_boxplot(pd.DataFrame(AnswerCount6))
# AnswerCount6 = AnswerCount6[0]


AnswerCount = [AnswerCount1, AnswerCount2, AnswerCount3, AnswerCount4, AnswerCount5, AnswerCount6]

# %%
len(AnswerCount1),len(AnswerCount2),len(AnswerCount3),len(AnswerCount4),len(AnswerCount5),len(AnswerCount6)
# Out:
# (148, 137, 337, 740, 2051, 4818)

# %%
plt.figure(dpi=200)

plt.boxplot(AnswerCount,
            labels = [str(i) for i in range(1,7)],
            patch_artist=True,
            showmeans=True,
            boxprops = {'color':'black','facecolor':'#1E90FF'},
            showfliers = False,
            meanprops = {'marker':'o','markerfacecolor':'red'},
            medianprops = {'linestyle':'--','color':'black'},)
plt.grid()
plt.ylabel('AnswerCount')
plt.xlabel('Interval')
# plt.yticks(range(2008, 2021), range(2008, 2021))
# plt.xticks(rotation=45)
plt.savefig('./pic/AnswerCount.jpg')
plt.show()

# %%
CommentCount1, CommentCount2, CommentCount3, CommentCount4, CommentCount5, CommentCount6 = df1['CommentCount'].dropna().to_list(),\
df2['CommentCount'].dropna().to_list(),\
df3['CommentCount'].dropna().to_list(),\
df4['CommentCount'].dropna().to_list(),\
df5['CommentCount'].dropna().to_list(),\
df6['CommentCount'].dropna().to_list()



# CommentCount1 = remove_filers_with_boxplot(pd.DataFrame(CommentCount1))
# CommentCount1 = CommentCount1[0]
#
# CommentCount2 = remove_filers_with_boxplot(pd.DataFrame(CommentCount2))
# CommentCount2 = CommentCount2[0]
#
# CommentCount3 = remove_filers_with_boxplot(pd.DataFrame(CommentCount3))
# CommentCount3 = CommentCount3[0]
#
# CommentCount4 = remove_filers_with_boxplot(pd.DataFrame(CommentCount4))
# CommentCount4 = CommentCount4[0]
#
# CommentCount5 = remove_filers_with_boxplot(pd.DataFrame(CommentCount5))
# CommentCount5 = CommentCount5[0]
#
# CommentCount6 = remove_filers_with_boxplot(pd.DataFrame(CommentCount6))
# CommentCount6 = CommentCount6[0]


CommentCount = [CommentCount1, CommentCount2, CommentCount3, CommentCount4, CommentCount5, CommentCount6]
len(CommentCount1),len(CommentCount2),len(CommentCount3),len(CommentCount4),len(CommentCount5),len(CommentCount6)
# Out:
# (148, 137, 337, 740, 2051, 4818)

# %%
plt.figure(dpi=200)

plt.boxplot(CommentCount,
            labels = [str(i) for i in range(1,7)],
            patch_artist=True,
            showmeans=True,
            boxprops = {'color':'black','facecolor':'#1E90FF'},
            showfliers = False,
            meanprops = {'marker':'o','markerfacecolor':'red'},
            medianprops = {'linestyle':'--','color':'black'},)
plt.grid()
plt.ylabel('CommentCount')
plt.xlabel('Interval')
# plt.yticks(range(2008, 2021), range(2008, 2021))
# plt.xticks(rotation=45)
plt.savefig('./pic/CommentCount.jpg')
plt.show()

# %%
FavoriteCount1, FavoriteCount2, FavoriteCount3, FavoriteCount4, FavoriteCount5, FavoriteCount6 = df1['FavoriteCount'].dropna().to_list(),\
df2['FavoriteCount'].dropna().to_list(),\
df3['FavoriteCount'].dropna().to_list(),\
df4['FavoriteCount'].dropna().to_list(),\
df5['FavoriteCount'].dropna().to_list(),\
df6['FavoriteCount'].dropna().to_list()


# FavoriteCount1 = remove_filers_with_boxplot(pd.DataFrame(FavoriteCount1))
# FavoriteCount1 = FavoriteCount1[0]
#
# FavoriteCount2 = remove_filers_with_boxplot(pd.DataFrame(FavoriteCount2))
# FavoriteCount2 = FavoriteCount2[0]
#
# FavoriteCount3 = remove_filers_with_boxplot(pd.DataFrame(FavoriteCount3))
# FavoriteCount3 = FavoriteCount3[0]
#
# FavoriteCount4 = remove_filers_with_boxplot(pd.DataFrame(FavoriteCount4))
# FavoriteCount4 = FavoriteCount4[0]
#
# FavoriteCount5 = remove_filers_with_boxplot(pd.DataFrame(FavoriteCount5))
# FavoriteCount5 = FavoriteCount5[0]
#
# FavoriteCount6 = remove_filers_with_boxplot(pd.DataFrame(FavoriteCount6))
# FavoriteCount6 = FavoriteCount6[0]


FavoriteCount = [FavoriteCount1, FavoriteCount2, FavoriteCount3, FavoriteCount4, FavoriteCount5, FavoriteCount6]
len(FavoriteCount1),len(FavoriteCount2),len(FavoriteCount3),len(FavoriteCount4),len(FavoriteCount5),len(FavoriteCount6)
# Out:
# (26, 31, 61, 155, 454, 1122)

# %%
plt.figure(dpi=200)

plt.boxplot(FavoriteCount,
            labels = [str(i) for i in range(1,7)],
            patch_artist=True,
            showmeans=True,
            boxprops = {'color':'black','facecolor':'#1E90FF'},
            showfliers = False,
            meanprops = {'marker':'o','markerfacecolor':'red'},
            medianprops = {'linestyle':'--','color':'black'},flierprops={'marker':'o'})
plt.grid()
plt.ylabel('FavoriteCount')
# plt.yticks(range(2008, 2021), range(2008, 2021))
# plt.xticks(rotation=45)
plt.xlabel('Interval')
plt.savefig('./pic/FavoriteCount.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(4)
means1 = [round(np.mean(Score1),2), round(np.mean(FavoriteCount1),2), round(np.mean(CommentCount1),2), round(np.mean(AnswerCount1),2)]
means2 = [round(np.mean(Score2),2), round(np.mean(FavoriteCount2),2), round(np.mean(CommentCount2),2), round(np.mean(AnswerCount2),2)]
means3 = [round(np.mean(Score3),2), round(np.mean(FavoriteCount3),2), round(np.mean(CommentCount3),2), round(np.mean(AnswerCount3),2)]
means4 = [round(np.mean(Score4),2), round(np.mean(FavoriteCount4),2), round(np.mean(CommentCount4),2), round(np.mean(AnswerCount4),2)]
means5 = [round(np.mean(Score5),2), round(np.mean(FavoriteCount5),2), round(np.mean(CommentCount5),2), round(np.mean(AnswerCount5),2)]
means6 = [round(np.mean(Score6),2), round(np.mean(FavoriteCount6),2), round(np.mean(CommentCount6),2), round(np.mean(AnswerCount6),2)]

listDate = ['Score', 'FavoriteCount', 'CommentCount', 'AnswerCount']

plt.figure(dpi=200)

means1 = [round(np.mean(Score1),2),round(np.mean(Score2),2),round(np.mean(Score3),2),round(np.mean(Score4),2),round(np.mean(Score5),2),round(np.mean(Score6),2)]
means2 = [round(np.mean(FavoriteCount1),2),round(np.mean(FavoriteCount2),2),round(np.mean(FavoriteCount3),2),round(np.mean(FavoriteCount4),2),round(np.mean(FavoriteCount5),2),round(np.mean(FavoriteCount6),2)]
means3 = [round(np.mean(CommentCount1),2),round(np.mean(CommentCount2),2),round(np.mean(CommentCount3),2),round(np.mean(CommentCount4),2),round(np.mean(CommentCount5),2),round(np.mean(CommentCount6),2)]
means4 = [round(np.mean(AnswerCount1),2),round(np.mean(AnswerCount2),2),round(np.mean(AnswerCount3),2),round(np.mean(AnswerCount4),2),round(np.mean(AnswerCount5),2),round(np.mean(AnswerCount6),2)]
x = range(1,7)

plt.xlabel("Interval")
plt.ylabel("Value")
plt.plot(x, means1,label="Score",color='red')
plt.plot(x, means2,  label="FavoriteCount", color='green')
plt.plot(x, means3, label="CommentCount", color='#1E90FF')
plt.plot(x, means4, label="AnswerCount", color='#FFD700')
plt.scatter(x, means1, marker='o', color='black',s=10)
plt.scatter(x, means2, marker='o', color='black',s=10)
plt.scatter(x, means3, marker='o', color='black',s=10)
plt.scatter(x, means4, marker='o', color='black',s=10)




plt.legend(loc='upper left')
plt.grid()
plt.savefig('./pic/post att.jpg', bbox_inches = 'tight')
